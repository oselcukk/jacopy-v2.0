# %% [markdown]
# # Problem 8 — Cartan structure equations (affine connection + local frame)
#
# **Goal.** For an affine connection $\nabla$ and a local frame
# $F = (X_a)$ (with dual coframe $e^a$), syntactically close the
# local-component forms and their structure equations with the engine:
#
# **(a)** Form-degree.
# $$
# \omega^a{}_b(\nabla)(V) := e^a(\nabla_V X_b),
# \quad
# Q_{ab}(\nabla, g)(V) := Q(\nabla, g)(V, X_a, X_b),
# \quad
# T^a(\nabla)(U,V) := e^a(T(\nabla)(U,V)),
# \quad
# R^a{}_b(\nabla)(U,V) := e^a(R(\nabla)(U,V)\,X_b)
# $$
# are defined. We will mechanically prove that $\omega$ and $Q$ are
# $C^\infty$-linear in $V$ (i.e. 1-forms) and that $T$ and $R$ are
# $C^\infty$-linear in both arguments and antisymmetric (i.e. 2-forms).
#
# **(b)** Cartan I & II.
# $$
# \begin{aligned}
# T^a &= d e^a + \omega^a{}_b \wedge e^b,\\
# R^a{}_b &= d \omega^a{}_b + \omega^a{}_c \wedge \omega^c{}_b.
# \end{aligned}
# $$
# We will reduce the difference of the two sides to $0$ by driving
# engine + `simplify` to a fixed point.

# %% [markdown]
# ## Setup
#
# With a connection $\nabla$, a metric $g$ and a $\dim 3$ local frame $F$
# we spin up two wrappers: `CartanFormPropertyProblem` for the form-degree
# proofs, and `CartanStructureProblem` for Cartan I/II.

# %%
# Make jacopy importable when the notebook is opened directly.
try:
    import jacopy  # noqa: F401
except ModuleNotFoundError:
    import sys
    from pathlib import Path
    here = Path.cwd().resolve()
    for candidate in (here, *here.parents):
        if (candidate / "jacopy" / "__init__.py").is_file():
            sys.path.insert(0, str(candidate))
            break
    import jacopy  # noqa: F401

# %%
from jacopy.algebra.derivation import Derivation
from jacopy.calculus.connection import connection
from jacopy.calculus.local_frame import local_frame
from jacopy.calculus.metric import metric
from jacopy.core.expr import Symbol
from jacopy.display.jupyter import display_chain
from jacopy.library import CartanStructureProblem, CartanFormPropertyProblem
from jacopy.proof.chain import ProofChain

nabla = connection("∇")
g = metric("g")
F = local_frame("F", dim=3)

U = Derivation("U", 0)
V = Derivation("V", 0)
f = Symbol("f")

probA = CartanFormPropertyProblem(nabla, F, metric=g)
probB = CartanStructureProblem(nabla, F)
probA, probB
# Out:
# (CartanFormPropertyProblem(∇,F,g), CartanStructureProblem(∇,F))

# %% [markdown]
# ## Part A — form-degree proofs
#
# Problem 8 (a): $\omega^a{}_b$ and $Q_{ab}$ are 1-forms; $T^a$ and
# $R^a{}_b$ are 2-forms. In every proof, LHS − RHS runs through the
# engine and reduces to $0$. We show one representative property per
# form below; in total `CartanFormPropertyProblem` exposes 14 `prove_*`
# methods.

# %% [markdown]
# ### A.1 — $\omega^a{}_b$ 1-form: $\langle \omega^a{}_b, f\,V\rangle = f\,\langle\omega^a{}_b, V\rangle$

# %%
res_omega = probA.prove_omega_scalar_linear_in_V("a", "b", f, V)
print("OK?", res_omega.ok)
print("final:", res_omega.final._repr_inner())
print(f"engine steps: {len(res_omega.steps)}")
display_chain(ProofChain(res_omega.steps))
# Out:
# OK? True
# final: 0
# engine steps: 4
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# \langle \omega^a_b(∇),\, f \, V \rangle \to \langle e^a,\, ∇_{(f * V)(X_b)} \rangle \quad \text{[\ensuremath{\omega} definition [∇,F]]\,(axiom)} \\
# ∇_{(f * V)(X_b)} \to f \, ∇_{V(X_b)} \quad \text{[∇\_X X-scalar pull [∇]]\,(axiom)} \\
# \langle e^a,\, f \, ∇_{V(X_b)} \rangle \to f \, \langle e^a,\, ∇_{V(X_b)} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle \omega^a_b(∇),\, V \rangle \to \langle e^a,\, ∇_{V(X_b)} \rangle \quad \text{[\ensuremath{\omega} definition [∇,F]]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ### A.2 — $Q_{ab}$ 1-form: $\langle Q_{ab}, f\,V\rangle = f\,\langle Q_{ab}, V\rangle$

# %%
res_Q = probA.prove_Q_scalar_linear_in_V("a", "b", f, V)
print("OK?", res_Q.ok)
print("final:", res_Q.final._repr_inner())
print(f"engine steps: {len(res_Q.steps)}")
display_chain(ProofChain(res_Q.steps))
# Out:
# OK? True
# final: 0
# engine steps: 3
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# \langle Q_{ab}(∇,g),\, f \, V \rangle \to f \, \langle Q_{ab}(∇,g),\, V \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle Q_{ab}(∇,g),\, V \rangle \to Q(∇,g)(V,X_{a,X_b)} \quad \text{[Q form definition [∇,g,F]]\,(axiom)} \\
# \langle Q_{ab}(∇,g),\, V \rangle \to Q(∇,g)(V,X_{a,X_b)} \quad \text{[Q form definition [∇,g,F]]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ### A.3 — $T^a$ 2-form (antisymmetry): $T^a(U, V) + T^a(V, U) = 0$

# %%
res_T = probA.prove_T_antisymmetric("a", U, V)
print("OK?", res_T.ok)
print("final:", res_T.final._repr_inner())
print(f"engine steps: {len(res_T.steps)}")
display_chain(ProofChain(res_T.steps))
# Out:
# OK? True
# final: 0
# engine steps: 4
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# T^a(∇)\!\left(U,\, V\right) \to \langle e^a,\, T(∇)(U,V) \rangle \quad \text{[T form definition [∇,F]]\,(axiom)} \\
# T^a(∇)\!\left(V,\, U\right) \to \langle e^a,\, T(∇)(V,U) \rangle \quad \text{[T form definition [∇,F]]\,(axiom)} \\
# T(∇)(V,U) \to -T(∇)(U,V) \quad \text{[T antisymmetry [∇]]\,(axiom)} \\
# \langle e^a,\, -T(∇)(U,V) \rangle \to -\langle e^a,\, T(∇)(U,V) \rangle \quad \text{[Pairing R-linearity]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ### A.4 — $R^a{}_b$ 2-form (antisymmetry): $R^a{}_b(U, V) + R^a{}_b(V, U) = 0$

# %%
res_R = probA.prove_R_antisymmetric("a", "b", U, V)
print("OK?", res_R.ok)
print("final:", res_R.final._repr_inner())
print(f"engine steps: {len(res_R.steps)}")
display_chain(ProofChain(res_R.steps))
# Out:
# OK? True
# final: 0
# engine steps: 4
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# R^a_b(∇)\!\left(U,\, V\right) \to \langle e^a,\, R(∇)(U,V)(X_b) \rangle \quad \text{[R form definition [∇,F]]\,(axiom)} \\
# R^a_b(∇)\!\left(V,\, U\right) \to \langle e^a,\, R(∇)(V,U)(X_b) \rangle \quad \text{[R form definition [∇,F]]\,(axiom)} \\
# R(∇)(V,U)(X_b) \to -R(∇)(U,V)(X_b) \quad \text{[R XY-antisymmetry [∇]]\,(axiom)} \\
# \langle e^a,\, -R(∇)(U,V)(X_b) \rangle \to -\langle e^a,\, R(∇)(U,V)(X_b) \rangle \quad \text{[Pairing R-linearity]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ## Part B.1 — Cartan I structure equation
#
# $$
# T^a(U, V) \;=\; (d e^a)(U, V) \;+\; \sum_b (\omega^a{}_b \wedge e^b)(U, V).
# $$
#
# The left side starts from the `T^a` form and unfolds into
# $\nabla_U V - \nabla_V U - [U,V]_{VF}$; the right side expands via the
# Cartan-Koszul intrinsic definition for `de^a` plus the sum-over-$b$
# wedge alternation. When both sides reduce to identical
# `Pairing`/`Act` atoms the difference drops to $0$.

# %%
lhs_I = probB.first_cartan_lhs(U, V, "a")
rhs_I = probB.first_cartan_rhs(U, V, "a")
print("Cartan I LHS:", lhs_I._repr_inner())
print("Cartan I RHS:", rhs_I._repr_inner())
# Out:
# Cartan I LHS: T^a(∇)(U, V)
# Cartan I RHS: (d(e^a)(U, V) + Σ_b̂∈F (ω^a_b̂(∇) ∧ e^b̂)(U, V))

# %%
res_I = probB.prove_first_cartan(U, V, "a")
chain_I = ProofChain(res_I.steps)
print("OK?", res_I.ok)
print("final:", res_I.final._repr_inner())
print(f"engine steps: {len(chain_I)}")
display_chain(chain_I)
# Out:
# OK? True
# final: 0
# engine steps: 49
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# T^a(∇)\!\left(U,\, V\right) \to \langle e^a,\, T(∇)(U,V) \rangle \quad \text{[T form definition [∇,F]]\,(axiom)} \\
# T(∇)(U,V) \to ∇_U(V) - ∇_V(U) - [U,V]_{VF} \quad \text{[T(∇)(X,Y) = ∇\_X Y \ensuremath{-} ∇\_Y X \ensuremath{-} [X,Y]\_VF [∇]]\,(axiom)} \\
# ∇_U(V) \to ∇_{U(\Sigma_{â∈F (\langlee^â, V\rangle * X_â))}} \quad \text{[∇\_X Y \ensuremath{\to} ∇\_X (\ensuremath{\Sigma}\_a e^a(Y)\ensuremath{\cdot}X\_a) [∇,F]]\,(axiom)} \\
# ∇_{U(\Sigma_{â∈F (\langlee^â, V\rangle * X_â))}} \to \Sigma_{â∈F ∇_{U((\langlee^â, V\rangle * X_â))}} \quad \text{[∇\_X \ensuremath{\Sigma}\_d body \ensuremath{\to} \ensuremath{\Sigma}\_d ∇\_X body [∇]]\,(axiom)} \\
# ∇_{U((\langlee^â, V\rangle * X_â))} \to U\!\left(\langle e^â,\, V \rangle\right) \, X_a + \langle e^â,\, V \rangle \, ∇_{U(X_â)} \quad \text{[∇\_X Y-Leibniz [∇]]\,(axiom)} \\
# ∇_{U(X_â)} \to \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# \Sigma_{â∈F ((U(\langlee^â, V\rangle) * X_{â) + (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)))}}}} \to \Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# ∇_V(U) \to ∇_{V(\Sigma_{â∈F (\langlee^â, U\rangle * X_â))}} \quad \text{[∇\_X Y \ensuremath{\to} ∇\_X (\ensuremath{\Sigma}\_a e^a(Y)\ensuremath{\cdot}X\_a) [∇,F]]\,(axiom)} \\
# ∇_{V(\Sigma_{â∈F (\langlee^â, U\rangle * X_â))}} \to \Sigma_{â∈F ∇_{V((\langlee^â, U\rangle * X_â))}} \quad \text{[∇\_X \ensuremath{\Sigma}\_d body \ensuremath{\to} \ensuremath{\Sigma}\_d ∇\_X body [∇]]\,(axiom)} \\
# ∇_{V((\langlee^â, U\rangle * X_â))} \to V\!\left(\langle e^â,\, U \rangle\right) \, X_a + \langle e^â,\, U \rangle \, ∇_{V(X_â)} \quad \text{[∇\_X Y-Leibniz [∇]]\,(axiom)} \\
# ∇_{V(X_â)} \to \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# \Sigma_{â∈F ((V(\langlee^â, U\rangle) * X_{â) + (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)))}}}} \to \Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# \langle e^a,\, \left(\Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}}\right) - \left(\Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}}\right) - [U,V]_{VF} \rangle \to \langle e^a,\, \Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}} \rangle + \langle e^a,\, -\left(\Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}}\right) \rangle + \langle e^a,\, -[U,V]_{VF} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}} \rangle \to \langle e^a,\, \Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} \rangle + \langle e^a,\, \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (U(\langlee^â, V\rangle) * X_â)} \rangle \to \Sigma_{â∈F \langlee^a, (U(\langlee^â, V\rangle) * X_â)\rangle} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, U\!\left(\langle e^â,\, V \rangle\right) \, X_a \rangle \to U\!\left(\langle e^â,\, V \rangle\right) \, \langle e^a,\, X_a \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_a \rangle \to \delta^a_â \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{â∈F (U(\langlee^â, V\rangle) * \delta^a_â)} \to U\!\left(\langle e^a,\, V \rangle\right) \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))}}} \rangle \to \Sigma_{â∈F \langlee^a, (\langlee^â, V\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ))\rangle}}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle e^â,\, V \rangle \, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)}} \rangle \to \langle e^â,\, V \rangle \, \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)}} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (\langle\omega^ĉ_{â(∇), U\rangle * X_ĉ)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^ĉ_â(∇),\, U \rangle \, X_c \rangle \to \langle \omega^ĉ_â(∇),\, U \rangle \, \langle e^a,\, X_c \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_c \rangle \to \delta^a_ĉ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), U\rangle * \delta^a_ĉ)}} \to \langle \omega^a_â(∇),\, U \rangle \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, -\left(\Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}}\right) \rangle \to -\langle e^a,\, \Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} + \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}} \rangle \to \langle e^a,\, \Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} \rangle + \langle e^a,\, \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (V(\langlee^â, U\rangle) * X_â)} \rangle \to \Sigma_{â∈F \langlee^a, (V(\langlee^â, U\rangle) * X_â)\rangle} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, V\!\left(\langle e^â,\, U \rangle\right) \, X_a \rangle \to V\!\left(\langle e^â,\, U \rangle\right) \, \langle e^a,\, X_a \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_a \rangle \to \delta^a_â \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{â∈F (V(\langlee^â, U\rangle) * \delta^a_â)} \to V\!\left(\langle e^a,\, U \rangle\right) \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, \Sigma_{â∈F (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))}}} \rangle \to \Sigma_{â∈F \langlee^a, (\langlee^â, U\rangle * \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ))\rangle}}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle e^â,\, U \rangle \, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)}} \rangle \to \langle e^â,\, U \rangle \, \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)}} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (\langle\omega^ĉ_{â(∇), V\rangle * X_ĉ)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^ĉ_â(∇),\, V \rangle \, X_c \rangle \to \langle \omega^ĉ_â(∇),\, V \rangle \, \langle e^a,\, X_c \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_c \rangle \to \delta^a_ĉ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{ĉ∈F (\langle\omega^ĉ_{â(∇), V\rangle * \delta^a_ĉ)}} \to \langle \omega^a_â(∇),\, V \rangle \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, -[U,V]_{VF} \rangle \to -\langle e^a,\, [U,V]_{VF} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \left(d\!\left(e^a\right)\right)\!\left(U,\, V\right) \to U\!\left(e^a\!\left(V\right)\right) - V\!\left(e^a\!\left(U\right)\right) - e^a\!\left([U,V]_{VF}\right) \quad \text{[d intrinsic (Koszul): (d\ensuremath{\omega})(X\_0, \ensuremath{\dots}, X\_p) = \ensuremath{\Sigma} \ensuremath{\pm}X\_i(\ensuremath{\omega}(\ensuremath{\dots},hat\_i,\ensuremath{\dots})) + \ensuremath{\Sigma} \ensuremath{\pm}\ensuremath{\omega}([X\_i,X\_j]\_VF, \ensuremath{\dots})]\,(axiom)} \\
# e^a\!\left(V\right) \to \langle e^a,\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# e^a\!\left(U\right) \to \langle e^a,\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# e^a\!\left([U,V]_{VF}\right) \to \langle e^a,\, [U,V]_{VF} \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \Sigma_{b̂∈F (\omega^a_b̂(∇) \wedge e^b̂)}\!\left(U,\, V\right) \to \Sigma_{b̂∈F (\omega^a_b̂(∇) \wedge e^b̂)(U, V)} \quad \text{[MultiEval(\ensuremath{\Sigma}\_d body, X\_1, \ensuremath{\dots}, X\_p) \ensuremath{\to} \ensuremath{\Sigma}\_d MultiEval(body, X\_1, \ensuremath{\dots}, X\_p)]\,(axiom)} \\
# \left(\omega^a_b̂(∇) \wedge e^b̂\right)\!\left(U,\, V\right) \to \omega^a_b̂(∇)\!\left(U\right) \, e^b̂\!\left(V\right) - \omega^a_b̂(∇)\!\left(V\right) \, e^b̂\!\left(U\right) \quad \text{[wedge alternating expansion: (\ensuremath{\alpha}\_1 \ensuremath{\wedge} \ensuremath{\dots} \ensuremath{\wedge} \ensuremath{\alpha}\_p)(X\_1, \ensuremath{\dots}, X\_p) \ensuremath{\to} \ensuremath{\Sigma}\_\ensuremath{\sigma} sign(\ensuremath{\sigma}) ∏\_i \ensuremath{\alpha}\_i(X\_{\ensuremath{\sigma}(i)})]\,(axiom)} \\
# \omega^a_b̂(∇)\!\left(U\right) \to \langle \omega^a_b̂(∇),\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# e^b̂\!\left(V\right) \to \langle e^b̂,\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^a_b̂(∇)\!\left(V\right) \to \langle \omega^a_b̂(∇),\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# e^b̂\!\left(U\right) \to \langle e^b̂,\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \Sigma_{b̂∈F ((\langle\omega^a_{b̂(∇), U\rangle * \langlee^b̂, V\rangle) + (-(\langle\omega^a_b̂(∇), V\rangle * \langlee^b̂, U\rangle)))}} \to \Sigma_{b̂∈F (\langle\omega^a_b̂(∇), U\rangle * \langlee^b̂, V\rangle)} + \Sigma_{b̂∈F (-(\langle\omega^a_b̂(∇), V\rangle * \langlee^b̂, U\rangle))} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# \Sigma_{b̂∈F (-(\langle\omega^a_b̂(∇), V\rangle * \langlee^b̂, U\rangle))} \to -\Sigma_{b̂∈F (\langle\omega^a_b̂(∇), V\rangle * \langlee^b̂, U\rangle)} \quad \text{[\ensuremath{\Sigma} over Neg: pull out]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ## Part B.2 — Cartan II structure equation
#
# $$
# R^a{}_b(U, V) \;=\; (d \omega^a{}_b)(U, V) \;+\; \sum_c (\omega^a{}_c \wedge \omega^c{}_b)(U, V).
# $$
#
# Same wrapper, same 24-rule engine bundle; the only difference: the
# left side starts from the $R^a{}_b$ form and unfolds into
# $\nabla_U \nabla_V X_b - \nabla_V \nabla_U X_b - \nabla_{[U,V]_{VF}} X_b$,
# while the right side expands $d\omega^a{}_b$ via Cartan-Koszul plus a
# second $\omega$ wedge.

# %%
lhs_II = probB.second_cartan_lhs(U, V, "a", "b")
rhs_II = probB.second_cartan_rhs(U, V, "a", "b")
print("Cartan II LHS:", lhs_II._repr_inner())
print("Cartan II RHS:", rhs_II._repr_inner())
# Out:
# Cartan II LHS: R^a_b(∇)(U, V)
# Cartan II RHS: (d(ω^a_b(∇))(U, V) + Σ_ĉ∈F (ω^a_ĉ(∇) ∧ ω^ĉ_b(∇))(U, V))

# %%
res_II = probB.prove_second_cartan(U, V, "a", "b")
chain_II = ProofChain(res_II.steps)
print("OK?", res_II.ok)
print("final:", res_II.final._repr_inner())
print(f"engine steps: {len(chain_II)}")
display_chain(chain_II)
# Out:
# OK? True
# final: 0
# engine steps: 54
# {\allowdisplaybreaks\scriptsize
# \begin{gather*}
# R^a_b(∇)\!\left(U,\, V\right) \to \langle e^a,\, R(∇)(U,V)(X_b) \rangle \quad \text{[R form definition [∇,F]]\,(axiom)} \\
# R(∇)(U,V)(X_b) \to ∇_{U(∇_{V(X_b))}} - ∇_{V(∇_{U(X_b))}} - ∇_{[U,V]_{VF(X_b)}} \quad \text{[R(∇)(X,Y)Z = ∇\_X ∇\_Y Z \ensuremath{-} ∇\_Y ∇\_X Z \ensuremath{-} ∇\_[X,Y]\_VF Z [∇]]\,(axiom)} \\
# ∇_{V(X_b)} \to \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * X_ĉ)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# ∇_{U(\Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * X_ĉ))}}} \to \Sigma_{ĉ∈F ∇_{U((\langle\omega^ĉ_{b(∇), V\rangle * X_ĉ))}}} \quad \text{[∇\_X \ensuremath{\Sigma}\_d body \ensuremath{\to} \ensuremath{\Sigma}\_d ∇\_X body [∇]]\,(axiom)} \\
# ∇_{U((\langle\omega^ĉ_{b(∇), V\rangle * X_ĉ))}} \to U\!\left(\langle \omega^ĉ_b(∇),\, V \rangle\right) \, X_c + \langle \omega^ĉ_b(∇),\, V \rangle \, ∇_{U(X_ĉ)} \quad \text{[∇\_X Y-Leibniz [∇]]\,(axiom)} \\
# ∇_{U(X_ĉ)} \to \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# \Sigma_{ĉ∈F ((U(\langle\omega^ĉ_{b(∇), V\rangle) * X_{ĉ) + (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)))}}}}}} \to \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# ∇_{U(X_b)} \to \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * X_ĉ)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# ∇_{V(\Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * X_ĉ))}}} \to \Sigma_{ĉ∈F ∇_{V((\langle\omega^ĉ_{b(∇), U\rangle * X_ĉ))}}} \quad \text{[∇\_X \ensuremath{\Sigma}\_d body \ensuremath{\to} \ensuremath{\Sigma}\_d ∇\_X body [∇]]\,(axiom)} \\
# ∇_{V((\langle\omega^ĉ_{b(∇), U\rangle * X_ĉ))}} \to V\!\left(\langle \omega^ĉ_b(∇),\, U \rangle\right) \, X_c + \langle \omega^ĉ_b(∇),\, U \rangle \, ∇_{V(X_ĉ)} \quad \text{[∇\_X Y-Leibniz [∇]]\,(axiom)} \\
# ∇_{V(X_ĉ)} \to \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# \Sigma_{ĉ∈F ((V(\langle\omega^ĉ_{b(∇), U\rangle) * X_{ĉ) + (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)))}}}}}} \to \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# ∇_{[U,V]_{VF(X_b)}} \to \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \quad \text{[∇\_V X\_b \ensuremath{\to} \ensuremath{\Sigma}\_c \ensuremath{\omega}^c\_b(V)\ensuremath{\cdot}X\_c [∇,F]]\,(axiom)} \\
# \langle e^a,\, \left(\Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}}\right) - \left(\Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}}\right) - \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \rangle \to \langle e^a,\, \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}} \rangle + \langle e^a,\, -\left(\Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}}\right) \rangle + \langle e^a,\, -\Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}} \rangle \to \langle e^a,\, \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} \rangle + \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (U(\langle\omega^ĉ_{b(∇), V\rangle) * X_ĉ)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, U\!\left(\langle \omega^ĉ_b(∇),\, V \rangle\right) \, X_c \rangle \to U\!\left(\langle \omega^ĉ_b(∇),\, V \rangle\right) \, \langle e^a,\, X_c \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_c \rangle \to \delta^a_ĉ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{ĉ∈F (U(\langle\omega^ĉ_{b(∇), V\rangle) * \delta^a_ĉ)}} \to U\!\left(\langle \omega^a_b(∇),\, V \rangle\right) \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))}}}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (\langle\omega^ĉ_{b(∇), V\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂))\rangle}}}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^ĉ_b(∇),\, V \rangle \, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)}} \rangle \to \langle \omega^ĉ_b(∇),\, V \rangle \, \langle e^a,\, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)}} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)}} \rangle \to \Sigma_{c1̂∈F \langlee^a, (\langle\omega^c1̂_{ĉ(∇), U\rangle * X_{c1}̂)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^c1̂_ĉ(∇),\, U \rangle \, X_{c1} \rangle \to \langle \omega^c1̂_ĉ(∇),\, U \rangle \, \langle e^a,\, X_{c1} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_{c1} \rangle \to \delta^a_{c1}̂ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), U\rangle * \delta^a_{c1}̂)}} \to \langle \omega^a_ĉ(∇),\, U \rangle \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, -\left(\Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}}\right) \rangle \to -\langle e^a,\, \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} + \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}} \rangle \to \langle e^a,\, \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} \rangle + \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (V(\langle\omega^ĉ_{b(∇), U\rangle) * X_ĉ)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, V\!\left(\langle \omega^ĉ_b(∇),\, U \rangle\right) \, X_c \rangle \to V\!\left(\langle \omega^ĉ_b(∇),\, U \rangle\right) \, \langle e^a,\, X_c \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_c \rangle \to \delta^a_ĉ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{ĉ∈F (V(\langle\omega^ĉ_{b(∇), U\rangle) * \delta^a_ĉ)}} \to V\!\left(\langle \omega^a_b(∇),\, U \rangle\right) \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))}}}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (\langle\omega^ĉ_{b(∇), U\rangle * \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂))\rangle}}}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^ĉ_b(∇),\, U \rangle \, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)}} \rangle \to \langle \omega^ĉ_b(∇),\, U \rangle \, \langle e^a,\, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)}} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)}} \rangle \to \Sigma_{c1̂∈F \langlee^a, (\langle\omega^c1̂_{ĉ(∇), V\rangle * X_{c1}̂)\rangle}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^c1̂_ĉ(∇),\, V \rangle \, X_{c1} \rangle \to \langle \omega^c1̂_ĉ(∇),\, V \rangle \, \langle e^a,\, X_{c1} \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_{c1} \rangle \to \delta^a_{c1}̂ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{c1̂∈F (\langle\omega^c1̂_{ĉ(∇), V\rangle * \delta^a_{c1}̂)}} \to \langle \omega^a_ĉ(∇),\, V \rangle \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \langle e^a,\, -\Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \rangle \to -\langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \rangle \quad \text{[Pairing R-linearity]\,(axiom)} \\
# \langle e^a,\, \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)}}} \rangle \to \Sigma_{ĉ∈F \langlee^a, (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * X_ĉ)\rangle}}} \quad \text{[\ensuremath{\langle}\ensuremath{\alpha}, \ensuremath{\Sigma}\_d body\ensuremath{\rangle} \ensuremath{\to} \ensuremath{\Sigma}\_d \ensuremath{\langle}\ensuremath{\alpha}, body\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, \langle \omega^ĉ_b(∇),\, [U,V]_{VF} \rangle \, X_c \rangle \to \langle \omega^ĉ_b(∇),\, [U,V]_{VF} \rangle \, \langle e^a,\, X_c \rangle \quad \text{[Pairing C\ensuremath{\infty}-linearity: \ensuremath{\langle}\ensuremath{\alpha}, f\ensuremath{\cdot}X\ensuremath{\rangle} = f\ensuremath{\cdot}\ensuremath{\langle}\ensuremath{\alpha}, X\ensuremath{\rangle}]\,(axiom)} \\
# \langle e^a,\, X_c \rangle \to \delta^a_ĉ \quad \text{[Frame duality [F]]\,(axiom)} \\
# \Sigma_{ĉ∈F (\langle\omega^ĉ_{b(∇), [U,V]_{VF\rangle * \delta^a_ĉ)}}} \to \langle \omega^a_b(∇),\, [U,V]_{VF} \rangle \, 1 \quad \text{[\ensuremath{\Sigma} over \ensuremath{\delta}(a,d)\ensuremath{\cdot}rest(d): contract]\,(axiom)} \\
# \left(d\!\left(\omega^a_b(∇)\right)\right)\!\left(U,\, V\right) \to U\!\left(\omega^a_b(∇)\!\left(V\right)\right) - V\!\left(\omega^a_b(∇)\!\left(U\right)\right) - \omega^a_b(∇)\!\left([U,V]_{VF}\right) \quad \text{[d intrinsic (Koszul): (d\ensuremath{\omega})(X\_0, \ensuremath{\dots}, X\_p) = \ensuremath{\Sigma} \ensuremath{\pm}X\_i(\ensuremath{\omega}(\ensuremath{\dots},hat\_i,\ensuremath{\dots})) + \ensuremath{\Sigma} \ensuremath{\pm}\ensuremath{\omega}([X\_i,X\_j]\_VF, \ensuremath{\dots})]\,(axiom)} \\
# \omega^a_b(∇)\!\left(V\right) \to \langle \omega^a_b(∇),\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^a_b(∇)\!\left(U\right) \to \langle \omega^a_b(∇),\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^a_b(∇)\!\left([U,V]_{VF}\right) \to \langle \omega^a_b(∇),\, [U,V]_{VF} \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \Sigma_{ĉ∈F (\omega^a_{ĉ(∇) \wedge \omega^ĉ_b(∇))}}\!\left(U,\, V\right) \to \Sigma_{ĉ∈F (\omega^a_{ĉ(∇) \wedge \omega^ĉ_b(∇))(U, V)}} \quad \text{[MultiEval(\ensuremath{\Sigma}\_d body, X\_1, \ensuremath{\dots}, X\_p) \ensuremath{\to} \ensuremath{\Sigma}\_d MultiEval(body, X\_1, \ensuremath{\dots}, X\_p)]\,(axiom)} \\
# \left(\omega^a_ĉ(∇) \wedge \omega^ĉ_b(∇)\right)\!\left(U,\, V\right) \to \omega^a_ĉ(∇)\!\left(U\right) \, \omega^ĉ_b(∇)\!\left(V\right) - \omega^a_ĉ(∇)\!\left(V\right) \, \omega^ĉ_b(∇)\!\left(U\right) \quad \text{[wedge alternating expansion: (\ensuremath{\alpha}\_1 \ensuremath{\wedge} \ensuremath{\dots} \ensuremath{\wedge} \ensuremath{\alpha}\_p)(X\_1, \ensuremath{\dots}, X\_p) \ensuremath{\to} \ensuremath{\Sigma}\_\ensuremath{\sigma} sign(\ensuremath{\sigma}) ∏\_i \ensuremath{\alpha}\_i(X\_{\ensuremath{\sigma}(i)})]\,(axiom)} \\
# \omega^a_ĉ(∇)\!\left(U\right) \to \langle \omega^a_ĉ(∇),\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^ĉ_b(∇)\!\left(V\right) \to \langle \omega^ĉ_b(∇),\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^a_ĉ(∇)\!\left(V\right) \to \langle \omega^a_ĉ(∇),\, V \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \omega^ĉ_b(∇)\!\left(U\right) \to \langle \omega^ĉ_b(∇),\, U \rangle \quad \text{[MultiEval(\ensuremath{\alpha}, V) \ensuremath{\to} \ensuremath{\langle}\ensuremath{\alpha}, V\ensuremath{\rangle} bridge for one-form \ensuremath{\alpha}]\,(axiom)} \\
# \Sigma_{ĉ∈F ((\langle\omega^a_{ĉ(∇), U\rangle * \langle\omega^ĉ_{b(∇), V\rangle) + (-(\langle\omega^a_{ĉ(∇), V\rangle * \langle\omega^ĉ_b(∇), U\rangle)))}}}} \to \Sigma_{ĉ∈F (\langle\omega^a_{ĉ(∇), U\rangle * \langle\omega^ĉ_b(∇), V\rangle)}} + \Sigma_{ĉ∈F (-(\langle\omega^a_{ĉ(∇), V\rangle * \langle\omega^ĉ_b(∇), U\rangle))}} \quad \text{[\ensuremath{\Sigma} over Sum: distribute]\,(axiom)} \\
# \Sigma_{ĉ∈F (-(\langle\omega^a_{ĉ(∇), V\rangle * \langle\omega^ĉ_b(∇), U\rangle))}} \to -\Sigma_{ĉ∈F (\langle\omega^a_{ĉ(∇), V\rangle * \langle\omega^ĉ_b(∇), U\rangle)}} \quad \text{[\ensuremath{\Sigma} over Neg: pull out]\,(axiom)}
# \end{gather*}
# }

# %% [markdown]
# ## Summary
#
# - **Part A**: $\omega$, $Q$ — 1-form (each with $V$-scalar-linearity
#   and $V$-additivity); $T$, $R$ — 2-form ($C^\infty$-linearity in both
#   arguments plus antisymmetry). 14 syntactic closures total are
#   available on `CartanFormPropertyProblem`; this notebook shows 4
#   representative proofs.
# - **Part B.1 / Cartan I**: $T^a = de^a + \omega^a{}_b \wedge e^b$ —
#   the `CartanStructureProblem` 22-rule bundle closes to $0$ in a single
#   `simplify` iteration.
# - **Part B.2 / Cartan II**: $R^a{}_b = d\omega^a{}_b + \omega^a{}_c \wedge \omega^c{}_b$ —
#   the same wrapper plus `CurvatureFormDefinition` +
#   `CurvatureDefinitionDefinition` (24 rules total); also closes in a
#   single iteration.
#
# The heart of the closure:
#
# 1. **Form definitions** ($T^a$, $R^a{}_b$, $\omega^a{}_b$) open the
#    atoms into the $\nabla$ + `Pairing` universe.
# 2. **`ConnectionEvalYFrameDecomposition`** expands $V$ into the frame
#    as $\sum_c P(e^c, V)\,X_c$; **`ConnectionFormDecomposition`**
#    rewrites $\nabla_V X_b$ as $\sum_c \omega^c{}_b(V)\,X_c$.
# 3. **`IndexedSum` push-in / Kronecker-contract** rules push the sum
#    binder to its destination on the right side and eliminate
#    $\delta$-factors.
# 4. **Cartan-Koszul** `ExteriorDIntrinsicDefinition` reduces the $de^a$
#    and $d\omega^a{}_b$ sides into $U(\cdot)$, $V(\cdot)$,
#    $[U,V]_{VF}$ components.
# 5. **Wedge alternation + arity-1 `MultiEval` → `Pairing` bridge**
#    expands the right-side $(\alpha \wedge \beta)(U,V)$ expressions as
#    $P(\alpha,U)\,P(\beta,V) - P(\alpha,V)\,P(\beta,U)$.
# 6. Finally `simplify` (notably `sort_product`) brings the `Product`
#    factors of both sides into a common canonical order; `collect_terms`
#    cancels the sign-paired terms and the residue drops to $0$.
